# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as pltcolors
from sklearn import linear_model, svm, discriminant_analysis, metrics
from scipy import optimize
import seaborn as sns

# %%
def plotLine(ax, xRange, w, x0, label, color='grey', linestyle='-', alpha=1.):
    """ Plot a (separating) line given the normal vector (weights) and point of intercept """
    if type(x0) == int or type(x0) == float or type(x0) == np.float64:
        x0 = [0, -x0 / w[1]]
    yy = -(w[0] / w[1]) * (xRange - x0[0]) + x0[1]
    ax.plot(xRange, yy, color=color, label=label, linestyle=linestyle)

def plotSvm(X, y, support=None, w=None, intercept=0., label='Data', separatorLabel='Separator',
            ax=None, bound=[[-1., 1.], [-1., 1.]]):
    """ Plot the SVM separation, and margin """
    if ax is None:
        fig, ax = plt.subplots(1)

    im = ax.scatter(X[:,0], X[:,1], c=y, cmap=cmap, alpha=0.5, label=label)
    if support is not None:
        ax.scatter(support[:,0], support[:,1], label='Support', s=80, facecolors='none',
                   edgecolors='y', color='y')
        print("Number of support vectors = %d" % (len(support)))
    if w is not None:
        xx = np.array(bound[0])
        plotLine(ax, xx, w, intercept, separatorLabel)
        # Захын зайг дүрслэх
        if support is not None:
            signedDist = np.matmul(support, w)
            margin = np.max(signedDist) - np.min(signedDist) * np.sqrt(np.dot(w, w))
            supportMaxNeg = support[np.argmin(signedDist)]
            plotLine(ax, xx, w, supportMaxNeg, 'Margin -', linestyle='-.', alpha=0.8)
            supportMaxPos = support[np.argmax(signedDist)]
            plotLine(ax, xx, w, supportMaxPos, 'Margin +', linestyle='--', alpha=0.8)
            ax.set_title('Margin = %.3f' % (margin))
    ax.legend(loc='upper left')
    ax.grid()
    ax.set_xlim(bound[0])
    ax.set_ylim(bound[1])
    cb = plt.colorbar(im, ax=ax)
    loc = np.arange(-1,1,1)
    cb.set_ticks(loc)
    cb.set_ticklabels(['-1','1'])

# %%
def plotHeatMap(X, classes, title=None, fmt='.2g', ax=None, xlabel=None, ylabel=None):
    """ Fix heatmap plot from Seaborn with pyplot 3.1.0, 3.1.1
        https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot
    """
    ax = sns.heatmap(X, xticklabels=classes, yticklabels=classes, annot=True, \
                     fmt=fmt, cmap=plt.cm.Blues, ax=ax)
    bottom, top = ax.get_ylim()
    ax.set_ylim(bottom + 0.5, top - 0.5)
    if title:
        ax.set_title(title)
    if xlabel:
        ax.set_xlabel(xlabel)
    if ylabel:
        ax.set_ylabel(ylabel)

def plotConfusionMatrix(yTrue, yEst, classes, title=None, fmt='.2g', ax=None):
    plotHeatMap(metrics.confusion_matrix(yTrue, yEst), classes, title, fmt, ax, xlabel='Estimations', \
                ylabel='True values');

# %%
def generateBatchXor(n, mu=0.5, sigma=0.5):
    """ Four gaussian clouds in a Xor fashion """
    X = np.random.normal(mu, sigma, (n, 2))
    yB0 = np.random.uniform(0, 1, n) > 0.5
    yB1 = np.random.uniform(0, 1, n) > 0.5
    y0 = 2. * yB0 - 1
    y1 = 2. * yB1 - 1
    X[:,0] *= y0
    X[:,1] *= y1
    X -= X.mean(axis=0)
    return X, y0*y1

# %%
colors = ['blue','red']
cmap = pltcolors.ListedColormap(colors)
nFeatures = 2
N = 100
xTrain, yTrain = generateBatchXor(2*N, sigma=0.25)
plotSvm(xTrain, yTrain)
xTest, yTest = generateBatchXor(2*N, sigma=0.25)
plotSvm(xTest, yTest)

# %% [markdown]
# ## Kernel trick танилцуулга
#
# Регресс гэх мэт шугаман тусгаарлагчийг ашиглах үед шугаман бус функцийг шийдвэрлэх уламжлалт арга бол анхны шинж чанаруудын зэрэгт болон үржвэрүүдийг ашиглан функцын орон зайг өргөжүүлэх явдал юм.
#
# Шугаман арганд хязгаарлалт бий. Жишээлбэл, XOR асуудлыг зөв шийдвэрийн муж гаргаагүй байна.
#
# SVM нь "Kernel trick" гэгддэг шинэ аргыг ашигласан.
#
# $h(x)$ функцийг ашиглан $x$-д хувиргалтыг хэрэгжүүлцгээе.
#
# Лагранж (Вольф) давхар (хос) асуудал дараах байдалтай байна.
# $$\begin{align}
# \mathcal{L}_d (\alpha)
# &= \sum_{i=0}^n \alpha_i - \frac 12 \sum_{i=0}^n \sum_{k=0}^n \alpha_i \alpha_k y_i y_k h(x_i)^T h(x_k) \\
# &= \sum_{i=0}^n \alpha_i - \frac 12 \sum_{i=0}^n \sum_{k=0}^n \alpha_i \alpha_k \langle y_i h(x_i), y_k  h(x_k) \rangle \\
# \end{align}$$
#
# __Subject to $\forall i\in 1..n$:__
# - $0 \le \alpha_i \le C$
# - $\sum_{i=0}^n \alpha_i y_i = 0$
#
# $ w = \sum_{i=0}^n \alpha_i y_i h(x_i)$ тул таамаглах функц байна:
# $$ f(x) = sign(w^T h(x) + b) = sign \left(\sum_{i=0}^n \alpha_i y_i \langle h(x_i), h(x) \rangle \right) $$
#
# Энэ таамаглалыг дэмжих вектор болох $\alpha_i > 0$-д тооцоолох шаардлагатай.
#
# Тохиромжтой болон таамаглал хоёулаа Kernel функц гэгддэг $K(x, x') = \langle h(x), h(x') \rangle$ дотоод бүтээгдэхүүн дээр суурилдаг. Энэ функц нь тэгш хэмтэй, хагас тодорхой байна.
#
# Gaussian Radial Basis Function (RBF) : $K(x, x') = exp(- \gamma \Vert x - x' \Vert^2 )$

# %% [markdown]
# ### G-RBF Kernel-тэй SVM-ийн хэрэгжүүлцгээе
#
# Шугаман SVM хэрэгжүүлэлт дээр хийсэн өөрчлөлтүүд нь _"# --->"_-ээр эхэлж, _"# <---"_ -ээр төгссөн блокуудад хавсаргасан болно.

# %%
class KernelSvmClassifier:

    def __init__(self, C, kernel):
        self.C = C
        self.kernel = kernel          # <---
        self.alpha = None
        self.supportVectors = None

    def fit(self, X, y):
        N = len(y)
        # --->
        # h(x) y -ийн Gram matrix
        hXX = np.apply_along_axis(lambda x1 : np.apply_along_axis(lambda x2:  self.kernel(x1, x2), 1, X),
                                  1, X)
        yp = y.reshape(-1, 1)
        GramHXy = hXX * np.matmul(yp, yp.T)
        # <---

        # Lagrange давхар асуудал
        def Ld0(G, alpha):
            return alpha.sum() - 0.5 * alpha.dot(alpha.dot(G))

        # алфа дээрх Лд-ийн хэсэгчилсэн уламжлал
        def Ld0dAlpha(G, alpha):
            return np.ones_like(alpha) - alpha.dot(G)

        # Хэлбэрийн альфа дээрх хязгаарлалт :
        # -  d - C*alpha  = 0
        # -  b - A*alpha >= 0
        A = np.vstack((-np.eye(N), np.eye(N)))             # <---
        b = np.hstack((np.zeros(N), self.C * np.ones(N)))  # <---
        constraints = ({'type': 'eq',   'fun': lambda a: np.dot(a, y),     'jac': lambda a: y},
                       {'type': 'ineq', 'fun': lambda a: b - np.dot(A, a), 'jac': lambda a: -A})

        # Эсрэгээр нь багасгах замаар дээд зэргээр нэмэгдүүлэх
        optRes = optimize.minimize(fun=lambda a: -Ld0(GramHXy, a),
                                   x0=np.ones(N),
                                   method='SLSQP',
                                   jac=lambda a: -Ld0dAlpha(GramHXy, a),
                                   constraints=constraints)
        self.alpha = optRes.x
        # --->
        epsilon = 1e-8
        supportIndices = self.alpha > epsilon
        self.supportVectors = X[supportIndices]
        self.supportAlphaY = y[supportIndices] * self.alpha[supportIndices]
        # <---

    def predict(self, X):
        """ Predict y values in {-1, 1} """
        # --->
        def predict1(x):
            x1 = np.apply_along_axis(lambda s: self.kernel(s, x), 1, self.supportVectors)
            x2 = x1 * self.supportAlphaY
            return np.sum(x2)

        d = np.apply_along_axis(predict1, 1, X)
        return 2 * (d > 0) - 1
        # <---

# %%
def GRBF(x1, x2):
    diff = x1 - x2
    return np.exp(-np.dot(diff, diff) * len(x1) / 2)

# Даалгавар нэмэлт 2 Kernel хэрэгжүүлэх аргын кодыг бичиж туршин үр дүнг харьцуулах

model30 = KernelSvmClassifier(C=5, kernel=GRBF)
model30.fit(xTrain, yTrain)

# %%
fig, ax = plt.subplots(1, figsize=(11, 7))
plotSvm(xTrain, yTrain, support=model30.supportVectors, label='Training', ax=ax)

# Тооцоолол, шийдвэрийн хил хязгаар
xx = np.linspace(-1, 1, 50)
X0, X1 = np.meshgrid(xx, xx)
xy = np.vstack([X0.ravel(), X1.ravel()]).T
Y30 = model30.predict(xy).reshape(X0.shape)
ax.contour(X0, X1, Y30, colors='k', levels=[-1, 0], alpha=0.3, linestyles=['-.', '-']);
# Out:
# Number of support vectors = 40

# %% [markdown]
# ## Scikit Learn SVM with Radial basis kernel

# %%
model31 = svm.SVC(kernel='rbf', C=10, gamma=1/2, shrinking=False)
model31.fit(xTrain, yTrain)
# Out:
# SVC(C=10, gamma=0.5, shrinking=False)

# %%
fig, ax = plt.subplots(1, figsize=(11, 7))
plotSvm(xTrain, yTrain, support=model31.support_vectors_, label='Training', ax=ax)

# Тооцоолол, шийдвэрийн хил хязгаар
Y31 = model31.predict(xy).reshape(X0.shape)
ax.contour(X0, X1, Y31, colors='k', levels=[-1, 0], alpha=0.3, linestyles=['-.', '-']);
# Out:
# Number of support vectors = 44

# %% [markdown]
# ### SVM with RBF performance on XOR

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 3))
for model, ax, title in zip([model30, model31], axes, ["Custom SVM with RBF", "SKLearn SVM with RBF"]):
    yEst3 = model.predict(xTest)
    plotConfusionMatrix(yTest, yEst3, colors, title, ax=ax)

# %% [markdown]
# Хоёр загварын таамаглал XOR жишээн дээр бараг таарч байна.

# %% [markdown]
# ## Дүгнэлт
#
# Шугаман салгах боломжгүй асуудлуудад зориулсан SVM ангилагчийн хүчийг бид харуулсан. 1990-ээд оны сүүлчээс эхлэн SVM нь олон асуудалд зориулсан машин сургалтын алгоритмын бүлийн тэргүүлэгч байсан. Энэ байдал 2010 оноос хойш бага зэрэг өөрчлөгдсөн бөгөөд гүнзгийрүүлсэн сургалт нь зарим ангиллын бодлогод илүү сайн гүйцэтгэлийг харуулсан. Гэсэн хэдий ч SVM нь олон нөхцөл байдалд илүү хүчтэй хэвээр байна. Жишээлбэл, SVM-д зориулсан сургалтын мэдээллийн хэмжээ нь гүнзгий суралцахад шаардагдах хэмжээнээс бага байна.
#
# ### Эндээс хаашаа явах вэ
#
# - Multiclass classifier using Neural Nets in Keras ([HTML](ClassificationMulti2Features-Keras.html) / [Jupyter](ClassificationMulti2Features-Keras.ipynb))
# - Multiclass classifier using Decision Trees ([HTML](ClassificationMulti2Features-Tree.html) / [Jupyter](ClassificationMulti2Features-Tree.ipynb))
# - Bivariate continuous function approximation with Linear Regression ([HTML](ClassificationContinuous2Features.html) / [Jupyter](ClassificationContinuous2Features.ipynb))
# - Bivariate continuous function approximation with k Nearest Neighbors ([HTML](ClassificationContinuous2Features-KNN.html) / [Jupyter](ClassificationContinuous2Features-KNN.ipynb))

# %% [markdown]
# # Даалгавар
# Нэмэлт 2 Kernel хэрэгжүүлэх аргын кодыг бичиж туршин үр дүнг Sklearn-ний үр дүнтэй харьцуулах

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as pltcolors
from sklearn import svm, metrics
from scipy import optimize
import seaborn as sns

# %%
def plotLine(ax, xRange, w, x0, label, color='grey', linestyle='-', alpha=1.):
    """ Plot a (separating) line given the normal vector (weights) and point of intercept """
    if type(x0) == int or type(x0) == float or type(x0) == np.float64:
        x0 = [0, -x0 / w[1]]
    yy = -(w[0] / w[1]) * (xRange - x0[0]) + x0[1]
    ax.plot(xRange, yy, color=color, label=label, linestyle=linestyle)

def plotSvm(X, y, support=None, w=None, intercept=0., label='Data', separatorLabel='Separator',
            ax=None, bound=[[-1., 1.], [-1., 1.]]):
    """ Plot the SVM separation, and margin """
    if ax is None:
        fig, ax = plt.subplots(1)

    im = ax.scatter(X[:,0], X[:,1], c=y, cmap=cmap, alpha=0.5, label=label)
    if support is not None:
        ax.scatter(support[:,0], support[:,1], label='Support', s=80, facecolors='none',
                   edgecolors='y', color='y')
        print("Number of support vectors = %d" % (len(support)))
    if w is not None:
        xx = np.array(bound[0])
        plotLine(ax, xx, w, intercept, separatorLabel)
        # Захын зайг дүрслэх
        if support is not None:
            signedDist = np.matmul(support, w)
            margin = np.max(signedDist) - np.min(signedDist) * np.sqrt(np.dot(w, w))
            supportMaxNeg = support[np.argmin(signedDist)]
            plotLine(ax, xx, w, supportMaxNeg, 'Margin -', linestyle='-.', alpha=0.8)
            supportMaxPos = support[np.argmax(signedDist)]
            plotLine(ax, xx, w, supportMaxPos, 'Margin +', linestyle='--', alpha=0.8)
            ax.set_title('Margin = %.3f' % (margin))
    ax.legend(loc='upper left')
    ax.grid()
    ax.set_xlim(bound[0])
    ax.set_ylim(bound[1])
    cb = plt.colorbar(im, ax=ax)
    loc = np.arange(-1,1,1)
    cb.set_ticks(loc)
    cb.set_ticklabels(['-1','1'])

def plotHeatMap(X, classes, title=None, fmt='.2g', ax=None, xlabel=None, ylabel=None):
    """ Fix heatmap plot from Seaborn with pyplot 3.1.0, 3.1.1
        https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot
    """
    ax = sns.heatmap(X, xticklabels=classes, yticklabels=classes, annot=True, \
                     fmt=fmt, cmap=plt.cm.Blues, ax=ax)
    bottom, top = ax.get_ylim()
    ax.set_ylim(bottom + 0.5, top - 0.5)
    if title:
        ax.set_title(title)
    if xlabel:
        ax.set_xlabel(xlabel)
    if ylabel:
        ax.set_ylabel(ylabel)

def plotConfusionMatrix(yTrue, yEst, classes, title=None, fmt='.2g', ax=None):
    plotHeatMap(metrics.confusion_matrix(yTrue, yEst), classes, title, fmt, ax, xlabel='Estimations', \
                ylabel='True values');

def generateBatchXor(n, mu=0.5, sigma=0.5):
    """ Four gaussian clouds in a Xor fashion """
    X = np.random.normal(mu, sigma, (n, 2))
    yB0 = np.random.uniform(0, 1, n) > 0.5
    yB1 = np.random.uniform(0, 1, n) > 0.5
    y0 = 2. * yB0 - 1
    y1 = 2. * yB1 - 1
    X[:,0] *= y0
    X[:,1] *= y1
    X -= X.mean(axis=0)
    return X, y0*y1

# %%
colors = ['blue','red']
cmap = pltcolors.ListedColormap(colors)

# Generate training and test data
nFeatures = 2
N = 100
xTrain, yTrain = generateBatchXor(2*N, sigma=0.25)
xTest, yTest = generateBatchXor(2*N, sigma=0.25)

# %%
class KernelSvmClassifier:
    def __init__(self, C, kernel):
        self.C = C
        self.kernel = kernel
        self.alpha = None
        self.supportVectors = None

    def fit(self, X, y):
        N = len(y)
        # h(x) y -ийн Gram matrix
        hXX = np.apply_along_axis(lambda x1 : np.apply_along_axis(lambda x2:  self.kernel(x1, x2), 1, X),
                                  1, X)
        yp = y.reshape(-1, 1)
        GramHXy = hXX * np.matmul(yp, yp.T)

        # Lagrange dual problem
        def Ld0(G, alpha):
            return alpha.sum() - 0.5 * alpha.dot(alpha.dot(G))

        # Gradient of the dual problem with respect to alpha
        def Ld0dAlpha(G, alpha):
            return np.ones_like(alpha) - alpha.dot(G)

        # Constraints
        A = np.vstack((-np.eye(N), np.eye(N)))
        b = np.hstack((np.zeros(N), self.C * np.ones(N)))
        constraints = ({'type': 'eq',   'fun': lambda a: np.dot(a, y),     'jac': lambda a: y},
                       {'type': 'ineq', 'fun': lambda a: b - np.dot(A, a), 'jac': lambda a: -A})

        # Minimize the negative dual to maximize the dual
        optRes = optimize.minimize(fun=lambda a: -Ld0(GramHXy, a),
                                   x0=np.ones(N),
                                   method='SLSQP',
                                   jac=lambda a: -Ld0dAlpha(GramHXy, a),
                                   constraints=constraints)
        self.alpha = optRes.x
        epsilon = 1e-8
        supportIndices = self.alpha > epsilon
        self.supportVectors = X[supportIndices]
        self.supportAlphaY = y[supportIndices] * self.alpha[supportIndices]

    def predict(self, X):
        """ Predict y values in {-1, 1} """
        def predict1(x):
            x1 = np.apply_along_axis(lambda s: self.kernel(s, x), 1, self.supportVectors)
            x2 = x1 * self.supportAlphaY
            return np.sum(x2)

        d = np.apply_along_axis(predict1, 1, X)
        return 2 * (d > 0) - 1

# Define additional kernel functions
def linear_kernel(x1, x2):
    return np.dot(x1, x2)

def polynomial_kernel(x1, x2):
    degree = 3  # You can adjust the degree
    coef0 = 1   # You can adjust the coef0
    return (np.dot(x1, x2) + coef0) ** degree

# %%
model_linear_custom = KernelSvmClassifier(C=5, kernel=linear_kernel)
model_linear_custom.fit(xTrain, yTrain)

# %%
model_poly_custom = KernelSvmClassifier(C=5, kernel=polynomial_kernel)
model_poly_custom.fit(xTrain, yTrain)

# %%
model_linear_sklearn = svm.SVC(kernel='linear', C=5)
model_linear_sklearn.fit(xTrain, yTrain)
# Out:
# SVC(C=5, kernel='linear')

# %%
model_poly_sklearn = svm.SVC(kernel='poly', degree=3, coef0=1, C=5)
model_poly_sklearn.fit(xTrain, yTrain)
# Out:
# SVC(C=5, coef0=1, kernel='poly')

# %%
xx = np.linspace(-1, 1, 100)
X0, X1 = np.meshgrid(xx, xx)
xy = np.vstack([X0.ravel(), X1.ravel()]).T

# %%
Y_linear_custom = model_linear_custom.predict(xy).reshape(X0.shape)
fig, ax = plt.subplots(1, figsize=(8, 6))
plotSvm(xTrain, yTrain, support=model_linear_custom.supportVectors, label='Training', ax=ax)
ax.contour(X0, X1, Y_linear_custom, colors='k', levels=[-1, 0], alpha=0.5, linestyles=['--', '-'])
ax.set_title('Custom SVM with Linear Kernel')
plt.show()
# Out:
# Number of support vectors = 192

# %%
Y_linear_sklearn = model_linear_sklearn.predict(xy).reshape(X0.shape)
fig, ax = plt.subplots(1, figsize=(8, 6))
plotSvm(xTrain, yTrain, support=model_linear_sklearn.support_vectors_, label='Training', ax=ax)
ax.contour(X0, X1, Y_linear_sklearn, colors='k', levels=[-1, 0], alpha=0.5, linestyles=['--', '-'])
ax.set_title('Scikit-Learn SVM with Linear Kernel')
plt.show()
# Out:
# Number of support vectors = 192

# %%
Y_poly_custom = model_poly_custom.predict(xy).reshape(X0.shape)
fig, ax = plt.subplots(1, figsize=(8, 6))
plotSvm(xTrain, yTrain, support=model_poly_custom.supportVectors, label='Training', ax=ax)
ax.contour(X0, X1, Y_poly_custom, colors='k', levels=[-1, 0], alpha=0.5, linestyles=['--', '-'])
ax.set_title('Custom SVM with Polynomial Kernel')
plt.show()
# Out:
# Number of support vectors = 31

# %%
Y_poly_sklearn = model_poly_sklearn.predict(xy).reshape(X0.shape)
fig, ax = plt.subplots(1, figsize=(8, 6))
plotSvm(xTrain, yTrain, support=model_poly_sklearn.support_vectors_, label='Training', ax=ax)
ax.contour(X0, X1, Y_poly_sklearn, colors='k', levels=[-1, 0], alpha=0.5, linestyles=['--', '-'])
ax.set_title('Scikit-Learn SVM with Polynomial Kernel')
plt.show()
# Out:
# Number of support vectors = 26

# %%
from sklearn.metrics import accuracy_score

# Custom Linear Kernel
y_pred_linear_custom = model_linear_custom.predict(xTest)
acc_linear_custom = accuracy_score(yTest, y_pred_linear_custom)
print(f"Custom Linear Kernel SVM Accuracy: {acc_linear_custom}")

# Scikit-Learn Linear Kernel
y_pred_linear_sklearn = model_linear_sklearn.predict(xTest)
acc_linear_sklearn = accuracy_score(yTest, y_pred_linear_sklearn)
print(f"Scikit-Learn Linear Kernel SVM Accuracy: {acc_linear_sklearn}")

# Custom Polynomial Kernel
y_pred_poly_custom = model_poly_custom.predict(xTest)
acc_poly_custom = accuracy_score(yTest, y_pred_poly_custom)
print(f"Custom Polynomial Kernel SVM Accuracy: {acc_poly_custom}")

# Scikit-Learn Polynomial Kernel
y_pred_poly_sklearn = model_poly_sklearn.predict(xTest)
acc_poly_sklearn = accuracy_score(yTest, y_pred_poly_sklearn)
print(f"Scikit-Learn Polynomial Kernel SVM Accuracy: {acc_poly_sklearn}")
# Out:
# Custom Linear Kernel SVM Accuracy: 0.535
# Scikit-Learn Linear Kernel SVM Accuracy: 0.695
# Custom Polynomial Kernel SVM Accuracy: 0.95
# Scikit-Learn Polynomial Kernel SVM Accuracy: 0.945

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
plotConfusionMatrix(yTest, y_pred_linear_custom, colors, title='Custom SVM with Linear Kernel', ax=axes[0, 0])
plotConfusionMatrix(yTest, y_pred_linear_sklearn, colors, title='Scikit-Learn SVM with Linear Kernel', ax=axes[0, 1])
plotConfusionMatrix(yTest, y_pred_poly_custom, colors, title='Custom SVM with Polynomial Kernel', ax=axes[1, 0])
plotConfusionMatrix(yTest, y_pred_poly_sklearn, colors, title='Scikit-Learn SVM with Polynomial Kernel', ax=axes[1, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# aaaaa

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, metrics
from scipy import optimize

# %%
def generate_xor_data(n_samples, sigma=0.5):
    X = np.random.randn(n_samples, 2) * sigma
    y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)
    y = 2 * y - 1  # Convert to labels {-1, 1}
    return X, y

# %%
class KernelSVM:
    def __init__(self, C=1.0, kernel=None):
        self.C = C
        self.kernel = kernel
        self.alpha = None
        self.support_vectors_ = None
        self.support_alpha_y = None

    def fit(self, X, y):
        N = len(y)
        # Compute Gram matrix
        K = np.array([[self.kernel(X[i], X[j]) for j in range(N)] for i in range(N)])
        P = np.outer(y, y) * K

        # Objective function for the dual problem
        def objective(alpha):
            return 0.5 * np.dot(alpha, np.dot(P, alpha)) - np.sum(alpha)

        # Gradient of the objective function
        def gradient(alpha):
            return np.dot(P, alpha) - np.ones(N)

        # Constraints
        constraints = {'type': 'eq', 'fun': lambda alpha: np.dot(alpha, y)}
        bounds = [(0, self.C) for _ in range(N)]

        # Solve the dual optimization problem
        result = optimize.minimize(objective, np.zeros(N), jac=gradient,
                                   bounds=bounds, constraints=constraints)
        alpha = result.x

        # Support vectors have non-zero lagrange multipliers
        idx = alpha > 1e-5
        self.alpha = alpha[idx]
        self.support_vectors_ = X[idx]
        self.support_y = y[idx]
        self.support_alpha_y = self.alpha * self.support_y

    def predict(self, X):
        def decision_function(x):
            K = np.array([self.kernel(x_i, x) for x_i in self.support_vectors_])
            return np.sum(self.support_alpha_y * K)
        return np.sign(np.array([decision_function(x) for x in X]))

# %%
def linear_kernel(x1, x2):
    return np.dot(x1, x2)

def polynomial_kernel(x1, x2, degree=3, coef0=1):
    return (np.dot(x1, x2) + coef0) ** degree

# %%
X_train, y_train = generate_xor_data(200, sigma=0.5)
X_test, y_test = generate_xor_data(200, sigma=0.5)

# %%
custom_svm_linear = KernelSVM(C=1.0, kernel=linear_kernel)
custom_svm_linear.fit(X_train, y_train)
y_pred_custom_linear = custom_svm_linear.predict(X_test)
acc_custom_linear = metrics.accuracy_score(y_test, y_pred_custom_linear)

# %%
custom_svm_poly = KernelSVM(C=1.0, kernel=lambda x1, x2: polynomial_kernel(x1, x2, degree=3, coef0=1))
custom_svm_poly.fit(X_train, y_train)
y_pred_custom_poly = custom_svm_poly.predict(X_test)
acc_custom_poly = metrics.accuracy_score(y_test, y_pred_custom_poly)

# %%
sklearn_svm_linear = svm.SVC(kernel='linear', C=1.0)
sklearn_svm_linear.fit(X_train, y_train)
y_pred_sklearn_linear = sklearn_svm_linear.predict(X_test)
acc_sklearn_linear = metrics.accuracy_score(y_test, y_pred_sklearn_linear)

# %%
sklearn_svm_poly = svm.SVC(kernel='poly', degree=3, coef0=1, C=1.0)
sklearn_svm_poly.fit(X_train, y_train)
y_pred_sklearn_poly = sklearn_svm_poly.predict(X_test)
acc_sklearn_poly = metrics.accuracy_score(y_test, y_pred_sklearn_poly)

# %%
print("Custom SVM with Linear Kernel Accuracy:", acc_custom_linear)
print("Scikit-Learn SVM with Linear Kernel Accuracy:", acc_sklearn_linear)
print("Custom SVM with Polynomial Kernel Accuracy:", acc_custom_poly)
print("Scikit-Learn SVM with Polynomial Kernel Accuracy:", acc_sklearn_poly)
# Out:
# Custom SVM with Linear Kernel Accuracy: 0.515
# Scikit-Learn SVM with Linear Kernel Accuracy: 0.375
# Custom SVM with Polynomial Kernel Accuracy: 0.96
# Scikit-Learn SVM with Polynomial Kernel Accuracy: 0.94

# %%
def plot_decision_boundary(clf, X, y, title):
    # Create a mesh grid
    h = 0.02  # step size
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    grid = np.c_[xx.ravel(), yy.ravel()]

    # Predict over the grid
    if isinstance(clf, KernelSVM):
        Z = clf.predict(grid)
    else:
        Z = clf.predict(grid)
    Z = Z.reshape(xx.shape)

    # Plot contours and data points
    plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.coolwarm)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.coolwarm)
    plt.title(title)
    plt.show()

# %%
plot_decision_boundary(custom_svm_linear, X_train, y_train, 'Custom SVM with Linear Kernel')
plot_decision_boundary(sklearn_svm_linear, X_train, y_train, 'Scikit-Learn SVM with Linear Kernel')
plot_decision_boundary(custom_svm_poly, X_train, y_train, 'Custom SVM with Polynomial Kernel')
plot_decision_boundary(sklearn_svm_poly, X_train, y_train, 'Scikit-Learn SVM with Polynomial Kernel')
